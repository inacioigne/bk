# %%
from sqlalchemy.orm import scoped_session, sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy import Column, Integer, String, Date, DATETIME, ForeignKey
from sqlalchemy.orm import relationship

# %%
from sqlalchemy import MetaData
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mariadb+mariadbconnector://admin:bkpass@127.0.0.1:3306/bk")

# %%
metadata_obj = MetaData()

# %%
from sqlalchemy import Table, Column, Integer, String

user = Table(
    "user",
    metadata_obj,
    Column("user_id", Integer, primary_key=True),
    Column("user_name", String(16), nullable=False),
    Column("email_address", String(60)),
    Column("nickname", String(50), nullable=False),
)

# %%
metadata_obj.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3292, in Engine.raw_connection(self)
#    3271 """Return a "raw" DBAPI connection from the connection pool.
#    3272
#    3273 The returned object is a proxied version of the DBAPI
#    (...)
#    3290
#    3291 """
# -> 3292 return self.pool.connect()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1268 if not fairy:
# -> 1269     fairy = _ConnectionRecord.checkout(pool)
#    1271     if threadconns is not None:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     166 try:
# --> 167     return self._create_connection()
#     168 except:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/mariadb/__init__.py:146, in connect(connectionclass, *args, **kwargs)
#     144         return c
# --> 146 connection = connectionclass(*args, **kwargs)
#     147 if not isinstance(connection, mariadb.connections.Connection):
#
# File /usr/local/lib/python3.12/site-packages/mariadb/connections.py:85, in Connection.__init__(self, *args, **kwargs)
#      83     kwargs["ssl"] = True
# ---> 85 super().__init__(*args, **kwargs)
#      86 self.autocommit = autocommit
#
# OperationalError: Can't connect to server on '127.0.0.1' (115)
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /workspace/api/test_api.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell://dev-container%_api.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> metadata_obj.create_all(engine)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/sql/schema.py:5828, in MetaData.create_all(self, bind, tables, checkfirst)
#    5804 def create_all(
#    5805     self,
#    5806     bind: _CreateDropBind,
#    5807     tables: Optional[_typing_Sequence[Table]] = None,
#    5808     checkfirst: bool = True,
#    5809 ) -> None:
#    5810     """Create all tables stored in this metadata.
#    5811
#    5812     Conditional by default, will not attempt to recreate tables already
#    (...)
#    5826
#    5827     """
# -> 5828     bind._run_ddl_visitor(
#    5829         ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    5830     )
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3242, in Engine._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3236 def _run_ddl_visitor(
#    3237     self,
#    3238     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    3239     element: SchemaItem,
#    3240     **kwargs: Any,
#    3241 ) -> None:
# -> 3242     with self.begin() as conn:
#    3243         conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#
# File /usr/local/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3232, in Engine.begin(self)
#    3205 @contextlib.contextmanager
#    3206 def begin(self) -> Iterator[Connection]:
#    3207     """Return a context manager delivering a :class:`_engine.Connection`
#    3208     with a :class:`.Transaction` established.
#    3209
#    (...)
#    3230
#    3231     """
# -> 3232     with self.connect() as conn:
#    3233         with conn.begin():
#    3234             yield conn
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3268, in Engine.connect(self)
#    3245 def connect(self) -> Connection:
#    3246     """Return a new :class:`_engine.Connection` object.
#    3247
#    3248     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3265
#    3266     """
# -> 3268     return self._connection_cls(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2430, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2428 elif should_wrap:
#    2429     assert sqlalchemy_exception is not None
# -> 2430     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2431 else:
#    2432     assert exc_info[1] is not None
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3292, in Engine.raw_connection(self)
#    3270 def raw_connection(self) -> PoolProxiedConnection:
#    3271     """Return a "raw" DBAPI connection from the connection pool.
#    3272
#    3273     The returned object is a proxied version of the DBAPI
#    (...)
#    3290
#    3291     """
# -> 3292     return self.pool.connect()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1261 @classmethod
#    1262 def _checkout(
#    1263     cls,
#    (...)
#    1266     fairy: Optional[_ConnectionFairy] = None,
#    1267 ) -> _ConnectionFairy:
#    1268     if not fairy:
# -> 1269         fairy = _ConnectionRecord.checkout(pool)
#    1271         if threadconns is not None:
#    1272             threadconns.current = weakref.ref(fairy)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     167     return self._create_connection()
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#     171     raise
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     165 if self._inc_overflow():
#     166     try:
# --> 167         return self._create_connection()
#     168     except:
#     169         with util.safe_reraise():
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     900     self.fresh = True
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/mariadb/__init__.py:146, in connect(connectionclass, *args, **kwargs)
#     143         c = pool.get_connection()
#     144         return c
# --> 146 connection = connectionclass(*args, **kwargs)
#     147 if not isinstance(connection, mariadb.connections.Connection):
#     148     raise mariadb.ProgrammingError("%s is not an instance of "
#     149                                    "mariadb.Connection" % connection)
#
# File /usr/local/lib/python3.12/site-packages/mariadb/connections.py:85, in Connection.__init__(self, *args, **kwargs)
#      82             kwargs["ssl_%s" % key] = ssl[key]
#      83     kwargs["ssl"] = True
# ---> 85 super().__init__(*args, **kwargs)
#      86 self.autocommit = autocommit
#      87 self.auto_reconnect = reconnect
#
# OperationalError: (mariadb.OperationalError) Can't connect to server on '127.0.0.1' (115)
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
class Item(Base):
    __tablename__ = 'item'
    id = Column(Integer, primary_key=True)
    itemnumber = Column(String(8))
    title = Column(String(200))
    barcode = Column(String(8))

    #relationship
    loan_active = relationship("LoanActive", back_populates="item")
    loan_historic = relationship("LoanHistoric", back_populates="item")

# %%
Base.metadata.create_all(bind=engine)

# %%
from src.db.models import *

# %%
engine = create_engine(
    "mariadb+mariadbconnector://admin:bkpass@127.0.0.1:3306/bk")

# %%
session = scoped_session(
    sessionmaker(autocommit=False, autoflush=False, bind=engine))

# %%
Base = declarative_base()
# Out:
# /tmp/ipykernel_58277/4196137762.py:1: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
Base.metadata.create_all(bind=engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3292, in Engine.raw_connection(self)
#    3271 """Return a "raw" DBAPI connection from the connection pool.
#    3272
#    3273 The returned object is a proxied version of the DBAPI
#    (...)
#    3290
#    3291 """
# -> 3292 return self.pool.connect()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1268 if not fairy:
# -> 1269     fairy = _ConnectionRecord.checkout(pool)
#    1271     if threadconns is not None:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     166 try:
# --> 167     return self._create_connection()
#     168 except:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/mariadb/__init__.py:146, in connect(connectionclass, *args, **kwargs)
#     144         return c
# --> 146 connection = connectionclass(*args, **kwargs)
#     147 if not isinstance(connection, mariadb.connections.Connection):
#
# File /usr/local/lib/python3.12/site-packages/mariadb/connections.py:85, in Connection.__init__(self, *args, **kwargs)
#      83     kwargs["ssl"] = True
# ---> 85 super().__init__(*args, **kwargs)
#      86 self.autocommit = autocommit
#
# OperationalError: Can't connect to server on '127.0.0.1' (115)
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /workspace/api/test_api.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://dev-container%_api.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> Base.metadata.create_all(bind=engine)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/sql/schema.py:5828, in MetaData.create_all(self, bind, tables, checkfirst)
#    5804 def create_all(
#    5805     self,
#    5806     bind: _CreateDropBind,
#    5807     tables: Optional[_typing_Sequence[Table]] = None,
#    5808     checkfirst: bool = True,
#    5809 ) -> None:
#    5810     """Create all tables stored in this metadata.
#    5811
#    5812     Conditional by default, will not attempt to recreate tables already
#    (...)
#    5826
#    5827     """
# -> 5828     bind._run_ddl_visitor(
#    5829         ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    5830     )
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3242, in Engine._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3236 def _run_ddl_visitor(
#    3237     self,
#    3238     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    3239     element: SchemaItem,
#    3240     **kwargs: Any,
#    3241 ) -> None:
# -> 3242     with self.begin() as conn:
#    3243         conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#
# File /usr/local/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3232, in Engine.begin(self)
#    3205 @contextlib.contextmanager
#    3206 def begin(self) -> Iterator[Connection]:
#    3207     """Return a context manager delivering a :class:`_engine.Connection`
#    3208     with a :class:`.Transaction` established.
#    3209
#    (...)
#    3230
#    3231     """
# -> 3232     with self.connect() as conn:
#    3233         with conn.begin():
#    3234             yield conn
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3268, in Engine.connect(self)
#    3245 def connect(self) -> Connection:
#    3246     """Return a new :class:`_engine.Connection` object.
#    3247
#    3248     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3265
#    3266     """
# -> 3268     return self._connection_cls(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2430, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2428 elif should_wrap:
#    2429     assert sqlalchemy_exception is not None
# -> 2430     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2431 else:
#    2432     assert exc_info[1] is not None
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3292, in Engine.raw_connection(self)
#    3270 def raw_connection(self) -> PoolProxiedConnection:
#    3271     """Return a "raw" DBAPI connection from the connection pool.
#    3272
#    3273     The returned object is a proxied version of the DBAPI
#    (...)
#    3290
#    3291     """
# -> 3292     return self.pool.connect()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1261 @classmethod
#    1262 def _checkout(
#    1263     cls,
#    (...)
#    1266     fairy: Optional[_ConnectionFairy] = None,
#    1267 ) -> _ConnectionFairy:
#    1268     if not fairy:
# -> 1269         fairy = _ConnectionRecord.checkout(pool)
#    1271         if threadconns is not None:
#    1272             threadconns.current = weakref.ref(fairy)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     167     return self._create_connection()
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#     171     raise
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     165 if self._inc_overflow():
#     166     try:
# --> 167         return self._create_connection()
#     168     except:
#     169         with util.safe_reraise():
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     900     self.fresh = True
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/mariadb/__init__.py:146, in connect(connectionclass, *args, **kwargs)
#     143         c = pool.get_connection()
#     144         return c
# --> 146 connection = connectionclass(*args, **kwargs)
#     147 if not isinstance(connection, mariadb.connections.Connection):
#     148     raise mariadb.ProgrammingError("%s is not an instance of "
#     149                                    "mariadb.Connection" % connection)
#
# File /usr/local/lib/python3.12/site-packages/mariadb/connections.py:85, in Connection.__init__(self, *args, **kwargs)
#      82             kwargs["ssl_%s" % key] = ssl[key]
#      83     kwargs["ssl"] = True
# ---> 85 super().__init__(*args, **kwargs)
#      86 self.autocommit = autocommit
#      87 self.auto_reconnect = reconnect
#
# OperationalError: (mariadb.OperationalError) Can't connect to server on '127.0.0.1' (115)
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
from src.db.init_db import initializeDatabase

# %%
class Base(DeclarativeBase):
    pass

class DefaultBase(Base):
    __abstract__ = True
    metadata = MetaData()

# %%
Base.metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3292, in Engine.raw_connection(self)
#    3271 """Return a "raw" DBAPI connection from the connection pool.
#    3272
#    3273 The returned object is a proxied version of the DBAPI
#    (...)
#    3290
#    3291 """
# -> 3292 return self.pool.connect()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1268 if not fairy:
# -> 1269     fairy = _ConnectionRecord.checkout(pool)
#    1271     if threadconns is not None:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     166 try:
# --> 167     return self._create_connection()
#     168 except:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/mariadb/__init__.py:146, in connect(connectionclass, *args, **kwargs)
#     144         return c
# --> 146 connection = connectionclass(*args, **kwargs)
#     147 if not isinstance(connection, mariadb.connections.Connection):
#
# File /usr/local/lib/python3.12/site-packages/mariadb/connections.py:85, in Connection.__init__(self, *args, **kwargs)
#      83     kwargs["ssl"] = True
# ---> 85 super().__init__(*args, **kwargs)
#      86 self.autocommit = autocommit
#
# OperationalError: Can't connect to server on '127.0.0.1' (115)
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /workspace/api/test_api.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell://dev-container%_api.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> Base.metadata.create_all(engine)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/sql/schema.py:5828, in MetaData.create_all(self, bind, tables, checkfirst)
#    5804 def create_all(
#    5805     self,
#    5806     bind: _CreateDropBind,
#    5807     tables: Optional[_typing_Sequence[Table]] = None,
#    5808     checkfirst: bool = True,
#    5809 ) -> None:
#    5810     """Create all tables stored in this metadata.
#    5811
#    5812     Conditional by default, will not attempt to recreate tables already
#    (...)
#    5826
#    5827     """
# -> 5828     bind._run_ddl_visitor(
#    5829         ddl.SchemaGenerator, self, checkfirst=checkfirst, tables=tables
#    5830     )
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3242, in Engine._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3236 def _run_ddl_visitor(
#    3237     self,
#    3238     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    3239     element: SchemaItem,
#    3240     **kwargs: Any,
#    3241 ) -> None:
# -> 3242     with self.begin() as conn:
#    3243         conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#
# File /usr/local/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3232, in Engine.begin(self)
#    3205 @contextlib.contextmanager
#    3206 def begin(self) -> Iterator[Connection]:
#    3207     """Return a context manager delivering a :class:`_engine.Connection`
#    3208     with a :class:`.Transaction` established.
#    3209
#    (...)
#    3230
#    3231     """
# -> 3232     with self.connect() as conn:
#    3233         with conn.begin():
#    3234             yield conn
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3268, in Engine.connect(self)
#    3245 def connect(self) -> Connection:
#    3246     """Return a new :class:`_engine.Connection` object.
#    3247
#    3248     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3265
#    3266     """
# -> 3268     return self._connection_cls(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2430, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2428 elif should_wrap:
#    2429     assert sqlalchemy_exception is not None
# -> 2430     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2431 else:
#    2432     assert exc_info[1] is not None
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3292, in Engine.raw_connection(self)
#    3270 def raw_connection(self) -> PoolProxiedConnection:
#    3271     """Return a "raw" DBAPI connection from the connection pool.
#    3272
#    3273     The returned object is a proxied version of the DBAPI
#    (...)
#    3290
#    3291     """
# -> 3292     return self.pool.connect()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:1269, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1261 @classmethod
#    1262 def _checkout(
#    1263     cls,
#    (...)
#    1266     fairy: Optional[_ConnectionFairy] = None,
#    1267 ) -> _ConnectionFairy:
#    1268     if not fairy:
# -> 1269         fairy = _ConnectionRecord.checkout(pool)
#    1271         if threadconns is not None:
#    1272             threadconns.current = weakref.ref(fairy)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     167     return self._create_connection()
#     168 except:
# --> 169     with util.safe_reraise():
#     170         self._dec_overflow()
#     171     raise
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:167, in QueuePool._do_get(self)
#     165 if self._inc_overflow():
#     166     try:
# --> 167         return self._create_connection()
#     168     except:
#     169         with util.safe_reraise():
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:902, in _ConnectionRecord.__connect(self)
#     900     self.fresh = True
#     901 except BaseException as e:
# --> 902     with util.safe_reraise():
#     903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.12/site-packages/mariadb/__init__.py:146, in connect(connectionclass, *args, **kwargs)
#     143         c = pool.get_connection()
#     144         return c
# --> 146 connection = connectionclass(*args, **kwargs)
#     147 if not isinstance(connection, mariadb.connections.Connection):
#     148     raise mariadb.ProgrammingError("%s is not an instance of "
#     149                                    "mariadb.Connection" % connection)
#
# File /usr/local/lib/python3.12/site-packages/mariadb/connections.py:85, in Connection.__init__(self, *args, **kwargs)
#      82             kwargs["ssl_%s" % key] = ssl[key]
#      83     kwargs["ssl"] = True
# ---> 85 super().__init__(*args, **kwargs)
#      86 self.autocommit = autocommit
#      87 self.auto_reconnect = reconnect
#
# OperationalError: (mariadb.OperationalError) Can't connect to server on '127.0.0.1' (115)
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
